# %%
#1. CREATE A DATAFAME

# %%
# load library
import pandas as pd
# create a datafame
datafame  = pd.DataFrame()
#add colums
datafame['Name']= ['Lemon','Apple','Banana']
datafame['Price']=[5,8,7]
datafame['License']=[False,True,True]
# show data
datafame
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
datafame.shape
# Out:
# (3, 3)

# %%
df = datafame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
# print colum name

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#           price
# count  3.000000
# mean   6.666667
# std    1.527525
# min    5.000000
# 25%    6.000000
# 50%    7.000000
# 75%    7.500000
# max    8.000000

# %%
# loc iloc
df.loc[(df.Price == 5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 5)| (df.Name == 'Banana ')]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 5)| (df.Name == 'Banana'),['Name','Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df. iloc[[2]]
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:2,0:-1]
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum =df.Price.sum()
print(sum)
# Out:
# 20

# %%
max = df.Price.max()
print(max)
# Out:
# 8

# %%
count = df['Price'].count()
print(count)
# Out:
# 3

# %%
# create row data
new = pd.Series(['Orage',10,True], index=['Name','Price','License'])
# append row
datafame.append(new, ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True
# 3   Orage     10     True

# %%
# append a colum
datafame['Location']= ['USA','VN','SIN']
datafame
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
# delete a row
datafame.drop(1, axis = 0).head(10)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      SIN

# %%
# deleta a column
datafame.drop('Location', axis = 1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
# replace
datafame['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
# rename columns
datafame.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True      SIN

# %%
# load libary
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load datafame
datafame = pd.read_csv(url)
#show data
datafame.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
data = datafame
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
# std: phuong sai
# mean: gia tri trung binh
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
data.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data.head(10)
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# ...

# %%
data = data.set_index(data['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
data.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
data[data['NOC']=='CAN'].head(10)
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# 4    1924                Chamonix  Ice Hockey      Ice Hockey  CAN
# 54   1928              St. Moritz  Ice Hockey      Ice Hockey  CAN
# 92   1932             Lake Placid  Ice Hockey      Ice Hockey  CAN
# 93   1932             Lake Placid     Skating  Figure skating  CAN
# 94   1932             Lake Placid     Skating   Speed skating  CAN
# 95   1932             Lake Placid     Skating   Speed skating  CAN
# 96   1932             Lake Placid     Skating   Speed skating  CAN
# 97   1932             Lake Placid     Skating   Speed skating  CAN
# 98   1932             Lake Placid     Skating   Speed skating  CAN
# 136  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  CAN
#
#           Event Event gender   Medal
# 4    ice hockey            M    Gold
# 54   ice hockey            M    Gold
# 92   ice hockey            M    Gold
# 93   individual            M  Bronze
# 94       10000m            M  Bronze
# ...

# %%
data[(data['Year']>=1990)&(data['Year']<=2006) & (data['NOC']=='USA')&(data['Event gender']=='W')&(data['Medal']=='Gold')].head(10)
# Out:
#       Year         City       Sport      Discipline  NOC       Event  \
# 1428  1992  Albertville     Skating  Figure skating  USA  individual
# 1430  1992  Albertville     Skating  Short Track S.  USA        500m
# 1431  1992  Albertville     Skating   Speed skating  USA       1000m
# 1432  1992  Albertville     Skating   Speed skating  USA        500m
# 1436  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# 1610  1994  Lillehammer     Skating  Short Track S.  USA        500m
# 1612  1994  Lillehammer     Skating   Speed skating  USA       1000m
# 1613  1994  Lillehammer     Skating   Speed skating  USA        500m
# 1617  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# 1812  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#      Event gender Medal
# 1428            W  Gold
# 1430            W  Gold
# 1431            W  Gold
# 1432            W  Gold
# 1436            W  Gold
# 1610            W  Gold
# 1612            W  Gold
# ...

# %%
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64

# %%
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data.drop('NOC', axis=1).head(10)
# Out:
#    Year      City       Sport      Discipline            Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating       individual            M
# 1  1924  Chamonix     Skating  Figure skating       individual            W
# 2  1924  Chamonix     Skating  Figure skating            pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# 5  1924  Chamonix    Biathlon        Biathlon  military patrol            M
# 6  1924  Chamonix     Skating  Figure skating            pairs            X
# 7  1924  Chamonix     Skating   Speed skating           10000m            M
# 8  1924  Chamonix     Skating   Speed skating           10000m            M
# 9  1924  Chamonix     Skating   Speed skating            1500m            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold
# 5  Silver
# 6  Silver
# 7    Gold
# 8  Silver
# 9    Gold

# %%
data.drop(data.columns[2:4], axis=1).head(10)
# Out:
#    Year      City  NOC            Event Event gender   Medal
# 0  1924  Chamonix  AUT       individual            M  Silver
# 1  1924  Chamonix  AUT       individual            W    Gold
# 2  1924  Chamonix  AUT            pairs            X    Gold
# 3  1924  Chamonix  BEL         four-man            M  Bronze
# 4  1924  Chamonix  CAN       ice hockey            M    Gold
# 5  1924  Chamonix  FIN  military patrol            M  Silver
# 6  1924  Chamonix  FIN            pairs            X  Silver
# 7  1924  Chamonix  FIN           10000m            M    Gold
# 8  1924  Chamonix  FIN           10000m            M  Silver
# 9  1924  Chamonix  FIN            1500m            M    Gold

# %%
data[data['NOC']!='CAN'].head(10)
# Out:
#     Year      City      Sport      Discipline  NOC            Event  \
# 0   1924  Chamonix    Skating  Figure skating  AUT       individual
# 1   1924  Chamonix    Skating  Figure skating  AUT       individual
# 2   1924  Chamonix    Skating  Figure skating  AUT            pairs
# 3   1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# 5   1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# 6   1924  Chamonix    Skating  Figure skating  FIN            pairs
# 7   1924  Chamonix    Skating   Speed skating  FIN           10000m
# 8   1924  Chamonix    Skating   Speed skating  FIN           10000m
# 9   1924  Chamonix    Skating   Speed skating  FIN            1500m
# 10  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#    Event gender   Medal
# 0             M  Silver
# 1             W    Gold
# 2             X    Gold
# 3             M  Bronze
# 5             M  Silver
# 6             X  Silver
# 7             M    Gold
# ...

# %%
data = pd.read_csv(url)
data.groupby('NOC').head(5)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2129  2006     Turin      Skiing  Cross Country S  EST             15km
# 2202  2006     Turin        Luge             Luge  LAT          singles
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
data.groupby(['Year','NOC']).head()
# Out:
#       Year      City       Sport      Discipline  NOC        Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT   individual
# 1     1924  Chamonix     Skating  Figure skating  AUT   individual
# 2     1924  Chamonix     Skating  Figure skating  AUT        pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL     four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN   ice hockey
# ...    ...       ...         ...             ...  ...          ...
# 2286  2006     Turin   Bobsleigh       Bobsleigh  USA      two-man
# 2287  2006     Turin     Curling         Curling  USA      curling
# 2288  2006     Turin  Ice Hockey      Ice Hockey  USA   ice hockey
# 2289  2006     Turin     Skating  Figure skating  USA  ice dancing
# 2290  2006     Turin     Skating  Figure skating  USA   individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# ...

# %%
#apply a function
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:10]
# Out:
# 0         INDIVIDUAL
# 1         INDIVIDUAL
# 2              PAIRS
# 3           FOUR-MAN
# 4         ICE HOCKEY
# 5    MILITARY PATROL
# 6              PAIRS
# 7             10000M
# 8             10000M
# 9              1500M
# Name: Event, dtype: object
